# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
tr = np.load("train_loss.npy")
ts = np.load("test_loss.npy")
print(tr.shape)
plt.figure()
plt.plot(tr)
plt.title("Train loss vs Our training bacth.")
plt.xlabel("Batch")
plt.ylabel("Loss")
plt.savefig("train_loss.png")
#tr = tr.tolist()
#ts = ts.tolist()
#print(tr, " ", ts)
#print(len(tr))
#x = range(0, len(tr))
#plot(x,tr)
# Out:
# (22500,)

# %%
print(ts.shape)
plt.figure()
plt.plot(ts)
plt.title("Test loss vs Our training bacth.")
plt.xlabel("Batch")
plt.ylabel("Loss")
plt.savefig("test_loss.png")
# Out:
# (2250,)
