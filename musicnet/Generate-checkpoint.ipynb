# %%
from pathlib import Path
import librosa
import torch
from argparse import ArgumentParser
import matplotlib
import h5py
import tqdm
from IPython.display import Audio, display
import  numpy as np
import sklearn

import sys
sys.path += ['../src']

#import utils
#import wavenet_models
#from utils import save_audio
#from wavenet import WaveNet
#from wavenet_generator import WavenetGenerator
#from nv_wavenet_generator import NVWavenetGenerator

# %%
# Inference params
checkpoint = Path('../checkpoints/pretrained_musicnet/lastmodel')
decoders = [0, 1, 2, 3, 4, 5]
batch_size = 1
rate = 16000
split_size = 20
file_paths = [Path('test.wav')]
print(file_paths)
for file in file_paths:
    print(file)
# Out:
# [WindowsPath('test.wav')]
# test.wav

# %%
import librosa.display
import matplotlib.pyplot as plt
import sys
matplotlib.use('agg')
file_paths = Path('pinao_1.wav')
data, rate = librosa.load(file_paths, sr=1600)
start = 12
duration = 5
stop = start +duration
audio_dst = data[start*160:stop*160]
print(audio_dst.shape)
librosa.display.waveplot(audio_dst, sr=1600)
plt.savefig("piano.png")
# Out:
# (800,)

# %%
import os
file_paths = Path('generated/')
print(file_paths)
for _,_,f in os.walk(file_paths):
    continue
for file in f:
    print(file)
# Out:
# generated
# Style0.wav
# Style1.wav
# Style2.wav
# Style3.wav
# Style4.wav
# Style5.wav

# %%
import librosa.display
import matplotlib.pyplot as plt
import sys
matplotlib.use('agg')
file_paths = Path('generated/')
for _,_,files in os.walk(file_paths):
    continue;
for fil in files:
    plt.figure(figsize=(20, 11))
    plt.title(str(fil)+"_v2")
    file = ("generated/" + str(fil))
    print(file)
    data, rate = librosa.load(file, sr=1600)
    print(data)
    start = 0
    duration = 5
    stop = start +duration
    audio_dst = data[start*1600:stop*1600]
    print("audio_dst", audio_dst)
    print(audio_dst.shape)
    #librosa.display.waveplot(audio_dst, sr=1600)
    D = librosa.amplitude_to_db(librosa.stft(audio_dst), ref=np.max)
    librosa.display.specshow(D, sr=1600, hop_length=32,y_axis='linear')
    plt.savefig(str(fil)+"_v2_32" +".png")
# Out:
# generated/Style0.wav
# [-0.06991229 -0.32788563 -0.46140492 ...  0.02163589  0.03841582
#  -0.08333632]
# audio_dst [-0.06991229 -0.32788563 -0.46140492 ...  0.02163589  0.03841582
#  -0.08333632]
# (8000,)
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\core\spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# generated/Style1.wav
# [ 0.09939189  0.45971775  0.01066592 ...  0.00274855 -0.02486782
#  -0.03743178]
# audio_dst [ 0.09939189  0.45971775  0.01066592 ...  0.00274855 -0.02486782
#  -0.03743178]
# (8000,)
# generated/Style2.wav
# [ 0.07748838 -0.12001354 -0.35347968 ... -0.01672899 -0.05794529
#   0.01549129]
# audio_dst [ 0.07748838 -0.12001354 -0.35347968 ... -0.01672899 -0.05794529
#   0.01549129]
# (8000,)
# generated/Style3.wav
# [ 0.00558469  0.27906215  0.0041683  ... -0.04015406 -0.02499785
#   0.00048498]
# audio_dst [ 0.00558469  0.27906215  0.0041683  ... -0.04015406 -0.02499785
#   0.00048498]
# (8000,)
# generated/Style4.wav
# [-0.15051076  0.04107602  0.291485   ... -0.00469268  0.00198257
#   0.00070562]
# audio_dst [-0.15051076  0.04107602  0.291485   ... -0.00469268  0.00198257
#   0.00070562]
# (8000,)
# generated/Style5.wav
# [-0.01323857 -0.17350563 -0.10898566 ... -0.03703151 -0.0203258
#  -0.00737456]
# audio_dst [-0.01323857 -0.17350563 -0.10898566 ... -0.03703151 -0.0203258
#  -0.00737456]
# (8000,)

# %%
file_paths = Path('pinao_1.wav')
data, rate = librosa.load(file_paths, sr=16000)
spectral_centroids = librosa.feature.spectral_centroid(data, sr=16000)[0]
spectral_centroids.shape
# Out:
# (2896,)

# %%
# Computing the time variable for visualization
plt.figure(figsize=(20, 11))
plt.title("centroid")
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)
# Normalising the spectral centroid for visualisation
def normalize(data, axis=0):
    return sklearn.preprocessing.minmax_scale(data, axis=axis)
#Plotting the Spectral Centroid along the waveform
librosa.display.waveplot(data, sr=1600, alpha=0.4)
plt.plot(frames, normalize(spectral_centroids), color='r')
plt.savefig("centroid.png")

# %%
file_paths = Path('generated/')
for _,_,files in os.walk(file_paths):
    continue;
for fil in files:
    plt.figure(figsize=(20, 11))
    fil = "generated/"+str(fil)
    data, rate = librosa.load(fil, sr=16000)
    spectral_centroids = librosa.feature.spectral_centroid(data, sr=16000)[0]
    spectral_centroids.shape
    # Computing the time variable for visualization
    plt.title("centroid")
    frames = range(len(spectral_centroids))
    t = librosa.frames_to_time(frames)
    # Normalising the spectral centroid for visualisation
    def normalize(data, axis=0):
        return sklearn.preprocessing.minmax_scale(data, axis=axis)
    #Plotting the Spectral Centroid along the waveform
    librosa.display.waveplot(data, sr=1600, alpha=0.4)
    plt.plot(frames, normalize(spectral_centroids), color='r')
    plt.savefig(str(fil)+"centroid.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """

# %%
import numpy as np
plt.figure(figsize=(30, 15))
matplotlib.use('agg')
file_paths = Path('pinao_1.wav')
data, rate = librosa.load(file_paths, sr=1600)
start = 12
duration = 30
stop = start +duration
audio_dst = data[start*1600:stop*1600]
print(audio_dst.shape)
D = librosa.amplitude_to_db(librosa.stft(audio_dst), ref=np.max)
plt.subplot(4, 2, 1)
librosa.display.specshow(D, sr=1600, hop_length=32,y_axis='linear')
plt.savefig("piano_fimg1600.png")
# Out:
# (48000,)
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\core\spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "

# %%
CQT = librosa.amplitude_to_db(librosa.cqt(audio_dst, sr=1600, n_bins = 40), ref=np.max)
librosa.display.specshow(CQT, sr=1600, hop_length=32,y_axis='linear')
plt.savefig("piano_fimg_cqt.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\lil.py:514: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not j.flags.writeable or j.dtype not in (np.int32, np.int64):

# %%
plt.figure(figsize=(30, 15))
matplotlib.use('agg')
file_paths = Path('voilins_1.wav')
data, rate = librosa.load(file_paths, sr=1600)
start = 12
duration = 30
stop = start +duration
audio_dst = data[start*1600:stop*1600]
print(audio_dst.shape)
D = librosa.amplitude_to_db(librosa.stft(audio_dst), ref=np.max)
plt.subplot(4, 2, 1)
librosa.display.specshow(D, sr=1600, hop_length=32,y_axis='linear')
plt.savefig("voilin_fimg1600.png")
# Out:
# (48000,)

# %%
import librosa.display
import matplotlib
import matplotlib.pyplot as plt
import sys, os
matplotlib.use('agg')
file_paths = Path('Bach_Solo_Cello/')
for _,_,files in os.walk(file_paths):
    continue;
max = []
min = []
mean = []
for fil in files:
    file = "Bach_Solo_Cello/"+str(fil)
    data, rate = librosa.load(file, sr=16000)
    start = 19
    duration  = 5
    stop = start +duration
    audio_dst = data[start*1600:stop*1600]
    spectral_centroids = librosa.feature.spectral_centroid(audio_dst, sr=16000)[0]
    spectral_centroids.shape
    # Computing the time variable for visualization
    
    plt.title("centroid")
    frames = range(len(spectral_centroids))
    #t = librosa.frames_to_time(frames)
    # Normalising the spectral centroid for visualisation
    def normalize(data, axis=0):
        return sklearn.preprocessing.minmax_scale(data, axis=axis)
    max.append(spectral_centroids.max())
    min.append(spectral_centroids.min())
    mean.append(spectral_centroids.mean())
    print(str(fil), "max", spectral_centroids.max())
    print(str(fil), "min", spectral_centroids.min())
    print(str(fil), "mean", spectral_centroids.mean())
    #Plotting the Spectral Centroid along the waveform
    #librosa.display.waveplot(data, sr=1600, alpha=0.4)
    #plt.plot(frames, normalize(spectral_centroids), color='r')
   # plt.savefig(str(fil)+"centroid.png")
# Out:
# 2217.wav max 819.0969400932872
# 2217.wav min 467.92862440949847
# 2217.wav mean 693.9990710434878
# 2218.wav max 1105.0248606611945
# 2218.wav min 693.9715639353619
# 2218.wav mean 889.3517819872394
# 2219.wav max 1286.0530179779494
# 2219.wav min 558.5439360826662
# 2219.wav mean 1093.6408250542618
# 2220.wav max 1200.4337884963002
# 2220.wav min 989.9204815319567
# 2220.wav mean 1108.4259625987443
# 2221.wav max 1526.0565953794978
# 2221.wav min 744.7888812618762
# 2221.wav mean 1183.9712408847022
# 2222.wav max 1592.900383788793
# 2222.wav min 1085.8307024462147
# 2222.wav mean 1392.8759876164181
# 2293.wav max 1485.3775659805974
# 2293.wav min 1057.8461734916527
# 2293.wav mean 1276.168629980495
# 2294.wav max 1617.540247996916
# 2294.wav min 779.9486811296159
# 2294.wav mean 1110.719409773582
# 2295.wav max 1344.3924598464555
# 2295.wav min 616.7133342264369
# 2295.wav mean 923.9463933178878
# 2296.wav max 755.8720561924412
# 2296.wav min 650.5919905216037
# 2296.wav mean 701.4296036753495
# 2297.wav max 744.719966616061
# 2297.wav min 558.4876914416539
# 2297.wav mean 666.1425665832536
# 2298.wav max 961.2887965197845
# 2298.wav min 610.725977825739
# 2298.wav mean 837.2179973886525

# %%
print("Bach_Solo_Cello average max:", np.max(max))
print("Bach_Solo_Cello average min:", np.min(min))
print("Bach_Solo_Cello average mean:", np.mean(mean))
# Out:
# Bach_Solo_Cello average max: 1617.540247996916
# Bach_Solo_Cello average min: 467.92862440949847
# Bach_Solo_Cello average mean: 989.8241224920062

# %%
import librosa.display
import matplotlib
import matplotlib.pyplot as plt
import sys, os
matplotlib.use('agg')
fd = ["Bach_Solo_Piano/", "Bach_Solo_Cello/", "Beethoven_Accompanied_Violin/", "Beethoven_Solo_Piano/", "Beethoven_String_Quartet/", "Cambini_Wind_Quintet/"]
#folder = "Bach_Solo_Piano/"
for folder in fd:
    max = []
    min = []
    mean = []
    file_paths = Path(folder)
    for _,_,files in os.walk(file_paths):
        continue;
    for fil in files:
        file = folder +str(fil)
        data, rate = librosa.load(file, sr=16000)
        start = [9, 19, 29, 39, 49, 59, 69, 79, 89, 99]
        duration  = 5
        for s in start:
            stop = s +duration
            audio_dst = data[s*1600:stop*1600]
            spectral_centroids = librosa.feature.spectral_centroid(audio_dst, sr=16000)[0]
            spectral_centroids.shape
            # Computing the time variable for visualization
    
            #frames = range(len(spectral_centroids))
            #t = librosa.frames_to_time(frames)
            # Normalising the spectral centroid for visualisation
            #def normalize(data, axis=0):
                #return sklearn.preprocessing.minmax_scale(data, axis=axis)
            max.append(spectral_centroids.max())
            min.append(spectral_centroids.min())
            mean.append(spectral_centroids.mean())
            #print(str(fil), "max", spectral_centroids.max())
            #print(str(fil), "min", spectral_centroids.min())
            #print(str(fil), "mean", spectral_centroids.mean())
    print(len(max))
    print(str(folder)," average max:", np.max(max))
    print(str(folder)," average min:", np.min(min))
    print(str(folder)," average mean:", np.mean(mean))
    plt.figure()
    n, bins, patches = plt.hist(max)
    plt.savefig((str(folder)+ "_max.png"))
    plt.figure()
    n, bins, patches = plt.hist(min)
    plt.savefig((str(folder)+"_min.png"))
    plt.figure()
    n, bins, patches = plt.hist(mean)
    plt.savefig((str(folder)+ "_mean.png"))
    #Plotting the Spectral Centroid along the waveform
    #librosa.display.waveplot(data, sr=1600, alpha=0.4)
    #plt.plot(frames, normalize(spectral_centroids), color='r')
   # plt.savefig(str(fil)+"centroid.png")
# Out:
# 390
# Bach_Solo_Piano/  average max: 1411.3649814881076
# Bach_Solo_Piano/  average min: 307.44726026873343
# Bach_Solo_Piano/  average mean: 681.6545065441431
# 120
# Bach_Solo_Cello/  average max: 3866.7771466751956
# Bach_Solo_Cello/  average min: 0.0
# Bach_Solo_Cello/  average mean: 890.3187488464417
# 220
# Beethoven_Accompanied_Violin/  average max: 3065.9411976942038
# Beethoven_Accompanied_Violin/  average min: 388.972554353749
# Beethoven_Accompanied_Violin/  average mean: 1031.0152836360514
# 930
# Beethoven_Solo_Piano/  average max: 7464.45362362345
# Beethoven_Solo_Piano/  average min: 0.0
# Beethoven_Solo_Piano/  average mean: 698.0152640981771
# 280
# Beethoven_String_Quartet/  average max: 4002.4443703691104
# Beethoven_String_Quartet/  average min: 340.4635022452244
# Beethoven_String_Quartet/  average mean: 1235.0141443829796
# 90
# Cambini_Wind_Quintet/  average max: 3041.075451421623
# Cambini_Wind_Quintet/  average min: 344.3250149180237
# Cambini_Wind_Quintet/  average mean: 725.3227490970281

# %%
print(len(max))
print(str(folder)," average max:", np.max(max))
print(str(folder)," average min:", np.min(min))
print(str(folder)," average mean:", np.mean(mean))
# Out:
# 39
# Bach_Solo_Piano/  average max: 1142.548679557162
# Bach_Solo_Piano/  average min: 365.0673087034848
# Bach_Solo_Piano/  average mean: 662.5588062892649

# %%
####滚将悉数
import librosa.display
import matplotlib
import matplotlib.pyplot as plt
import sys, os
matplotlib.use('agg')
fd = ["Bach_Solo_Piano/", "Bach_Solo_Cello/", "Beethoven_Accompanied_Violin/", "Beethoven_Solo_Piano/", "Beethoven_String_Quartet/", "Cambini_Wind_Quintet/"]
#folder = "Bach_Solo_Piano/"
for folder in fd:
    max = []
    min = []
    mean = []
    file_paths = Path(folder)
    for _,_,files in os.walk(file_paths):
        continue;
    for fil in files:
        file = folder +str(fil)
        data, rate = librosa.load(file, sr=16000)
        start = [9, 19, 29, 39, 49, 59, 69, 79, 89, 99]
        duration  = 5
        for s in start:
            stop = s +duration
            audio_dst = data[s*1600:stop*1600]
            #spectral_centroids = librosa.feature.spectral_centroid(audio_dst, sr=16000)[0]
            spectral_rolloff = librosa.feature.spectral_rolloff(audio_dst+0.01, sr=16000)[0]
            spectral_rolloff.shape
            # Computing the time variable for visualization
    
            #frames = range(len(spectral_centroids))
            #t = librosa.frames_to_time(frames)
            # Normalising the spectral centroid for visualisation
            #def normalize(data, axis=0):
                #return sklearn.preprocessing.minmax_scale(data, axis=axis)
            max.append(spectral_rolloff .max())
            min.append(spectral_rolloff .min())
            mean.append(spectral_rolloff .mean())
            #print(str(fil), "max", spectral_centroids.max())
            #print(str(fil), "min", spectral_centroids.min())
            #print(str(fil), "mean", spectral_centroids.mean())
    print(len(max))
    print(str(folder)," average max:", np.max(max))
    print(str(folder)," average min:", np.min(min))
    print(str(folder)," average mean:", np.mean(mean))
    plt.figure()
    n, bins, patches = plt.hist(max)
    plt.savefig((str(folder)+ "_max.png"))
    plt.figure()
    n, bins, patches = plt.hist(min)
    plt.savefig((str(folder)+"_min.png"))
    plt.figure()
    n, bins, patches = plt.hist(mean)
    plt.savefig((str(folder)+ "_mean.png"))
    plt.close('all')
    #Plotting the Spectral Centroid along the waveform
    #librosa.display.waveplot(data, sr=1600, alpha=0.4)
    #plt.plot(frames, normalize(spectral_centroids), color='r')
   # plt.savefig(str(fil)+"centroid.png")
# Out:
# 390
# Bach_Solo_Piano/  average max: 2015.625
# Bach_Solo_Piano/  average min: 7.8125
# Bach_Solo_Piano/  average mean: 986.6261017628206
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# 120
# Bach_Solo_Cello/  average max: 3007.8125
# Bach_Solo_Cello/  average min: 7.8125
# Bach_Solo_Cello/  average mean: 1462.3697916666667
# 220
# Beethoven_Accompanied_Violin/  average max: 5304.6875
# Beethoven_Accompanied_Violin/  average min: 7.8125
# Beethoven_Accompanied_Violin/  average mean: 1546.8239524147727
# 930
# Beethoven_Solo_Piano/  average max: 5070.3125
# Beethoven_Solo_Piano/  average min: 7.8125
# Beethoven_Solo_Piano/  average mean: 922.0230594758065
# 280
# Beethoven_String_Quartet/  average max: 4789.0625
# Beethoven_String_Quartet/  average min: 7.8125
# Beethoven_String_Quartet/  average mean: 2087.0657784598216
# 90
# Cambini_Wind_Quintet/  average max: 2226.5625
# Cambini_Wind_Quintet/  average min: 7.8125
# Cambini_Wind_Quintet/  average mean: 861.7078993055555

# %%
#mfcc
sr=16000
x, fs = librosa.load('p.wav')
librosa.display.waveplot(x, sr=sr)
mfccs = librosa.feature.mfcc(x, sr=fs)
print(mfccs.shape)
print(mfccs)
#Displaying  the MFCCs:
plt.figure()
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
#n, bins, patches = plt.hist(mean)
plt.savefig("test_mfcc_p.png")
plt.close('all')
# Out:
# (20, 3991)
# [[-583.65533   -576.38916   -581.9331    ... -584.2729    -584.50146
#   -584.40094  ]
#  [   9.975946    19.904608    12.412673  ...    9.1349535    8.813343
#      8.948088 ]
#  [   9.846854    18.78482     12.286562  ...    9.101857     8.7850065
#      8.8978195]
#  ...
#  [   3.1184878    4.108704     5.059106  ...    6.621291     6.4573717
#      5.3421707]
#  [   2.7756295    3.7706826    4.622056  ...    6.393485     6.2169833
#      5.041644 ]
#  [   2.4768314    3.4085784    4.227958  ...    6.1677       5.9726152
#      4.7493787]]

# %%
#zero_crossing_test
sr=1600
plt.figure()
x, fs = librosa.load('p.wav',sr =sr)
librosa.display.waveplot(x, sr=sr)
zero_crossing_rate = librosa.feature.zero_crossing_rate(x, hop_length=64)
print("sample size:",x)
print("zero size:", zero_crossing_rate.shape)
print(zero_crossing_rate)
#Displaying  the MFCCs:
#plt.subplot(zero_crossing_rate)
#n, bins, patches = plt.hist(mean)
#plt.savefig("test_zerocross_p.png")
#plt.close('all')
# Out:
# sample size: [-5.1699544e-07  5.4943928e-07 -5.4328024e-07 ...  5.2625796e-06
#  -3.3467479e-06  0.0000000e+00]
# zero size: (1, 2317)
# [[0.02001953 0.02050781 0.02148438 ... 0.01904297 0.01611328 0.015625  ]]

# %%
####zero_crossing_rate
import librosa.display
import matplotlib
import matplotlib.pyplot as plt
import sys, os
matplotlib.use('agg')
fd = ["Bach_Solo_Piano/", "Bach_Solo_Cello/", "Beethoven_Accompanied_Violin/", "Beethoven_Solo_Piano/", "Beethoven_String_Quartet/", "Cambini_Wind_Quintet/"]
#folder = "Bach_Solo_Piano/"
for folder in fd:
    max = []
    min = []
    mean = []
    file_paths = Path(folder)
    for _,_,files in os.walk(file_paths):
        continue;
    for fil in files:
        file = folder +str(fil)
        data, rate = librosa.load(file, sr=16000)
        start = [9, 19, 29, 39, 49, 59, 69, 79, 89, 99]
        duration  = 5
        for s in start:
            stop = s +duration
            audio_dst = data[s*1600:stop*1600]
            #spectral_centroids = librosa.feature.spectral_centroid(audio_dst, sr=16000)[0]
            zero_crossing_rate = librosa.feature.zero_crossing_rate(audio_dst,hop_length=128)
            # Computing the time variable for visualization
    
            #frames = range(len(spectral_centroids))
            #t = librosa.frames_to_time(frames)
            # Normalising the spectral centroid for visualisation
            #def normalize(data, axis=0):
                #return sklearn.preprocessing.minmax_scale(data, axis=axis)
            max.append(zero_crossing_rate .max())
            min.append(zero_crossing_rate .min())
            mean.append(zero_crossing_rate .mean())
            #print(str(fil), "max", spectral_centroids.max())
            #print(str(fil), "min", spectral_centroids.min())
            #print(str(fil), "mean", spectral_centroids.mean())
    print(len(max))
    print(str(folder)," average max:", np.max(max))
    print(str(folder)," average min:", np.min(min))
    print(str(folder)," average mean:", np.mean(mean))
    plt.figure()
    n, bins, patches = plt.hist(max)
    plt.savefig(("zero_crossing/"+str(folder).strip( '/' )+ "_max.png"))
    plt.figure()
    n, bins, patches = plt.hist(min)
    plt.savefig(("zero_crossing/"+str(folder).strip( '/' )+"_min.png"))
    plt.figure()
    n, bins, patches = plt.hist(mean)
    plt.savefig(("zero_crossing/"+str(folder).strip( '/' )+ "_mean.png"))
    plt.close('all')
    #Plotting the Spectral Centroid along the waveform
    #librosa.display.waveplot(data, sr=1600, alpha=0.4)
    #plt.plot(frames, normalize(spectral_centroids), color='r')
   # plt.savefig(str(fil)+"centroid.png")
# Out:
# 390
# Bach_Solo_Piano/  average max: 0.1337890625
# Bach_Solo_Piano/  average min: 0.00048828125
# Bach_Solo_Piano/  average mean: 0.05802653292887667
# 120
# Bach_Solo_Cello/  average max: 0.2802734375
# Bach_Solo_Cello/  average min: 0.0
# Bach_Solo_Cello/  average mean: 0.04923102161871693
# 220
# Beethoven_Accompanied_Violin/  average max: 0.28759765625
# Beethoven_Accompanied_Violin/  average min: 0.00634765625
# Beethoven_Accompanied_Violin/  average mean: 0.06846703643578643
# 930
# Beethoven_Solo_Piano/  average max: 0.3896484375
# Beethoven_Solo_Piano/  average min: 0.0
# Beethoven_Solo_Piano/  average mean: 0.05426357286866359
# 280
# Beethoven_String_Quartet/  average max: 0.5234375
# Beethoven_String_Quartet/  average min: 0.00244140625
# Beethoven_String_Quartet/  average mean: 0.08055995673008787
# 90
# Cambini_Wind_Quintet/  average max: 0.1669921875
# Cambini_Wind_Quintet/  average min: 0.00341796875
# Cambini_Wind_Quintet/  average mean: 0.05908082561728395

# %%
s="bac/"
s.strip( '/' )
# Out:
# 'bac'

# %%
n, bins, patches = plt.hist(max)
plt.show()
plt.savefig("Cello_max.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
import numpy as np
plt.figure()
S = librosa.feature.melspectrogram(y=audio_dst, sr=160)
ax = plt.subplot(2,1,2)
librosa.display.specshow(librosa.power_to_db(S, ref=np.max),
                         x_axis='time', y_axis='mel')
plt.subplot(2,1,1, sharex=ax)
librosa.display.waveplot(y_beat_times, sr=160, label='Beat clicks')
plt.legend()
plt.xlim(15, 30)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-66c95d4476ff> in <module>
#       6                          x_axis='time', y_axis='mel')
#       7 plt.subplot(2,1,1, sharex=ax)
# ----> 8 librosa.display.waveplot(y_beat_times, sr=160, label='Beat clicks')
#       9 plt.legend()
#      10 plt.xlim(15, 30)
#
# NameError: name 'y_beat_times' is not defined

# %%
from pathlib import Path
import matplotlib
import matplotlib.pyplot as plt
import librosa.display
matplotlib.use('TkAgg')
file_paths = Path('test.wav')#,Path('./generated/Style1.wav'),Path('./generated/Style2.wav'),]
print(file_paths)
plt.figure(figsize=(14, 5))
data, rate = librosa.load(file_paths, sr=1600)
librosa.display.waveplot(data, sr=10)
#xs.append(torch.tensor(data).unsqueeze(0).float().cuda())
plt.show()
# Out:
# test.wav

# %%
import librosa.display
librosa.display.waveplot(xs, sr=1600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e0d0b419e7bb> in <module>
#       1 import librosa.display
# ----> 2 librosa.display.waveplot(xs, sr=1600)
#
# NameError: name 'xs' is not defined

# %%
def disp(x, decoder_ix):
    wav = utils.inv_mu_law(x.cpu().numpy())
    print(f'Decoder: {decoder_ix}')
    print(f'X min: {x.min()}, max: {x.max()}')

    display(Audio(wav.squeeze(), rate=rate))
        
def extract_id(path):
    decoder_id = str(path)[:-4].split('_')[-1]
    return int(decoder_id)

# %%
class args:
    def __init__(self):
        self.latent_d = 64    # 名称
        self.repeat_num = 6     # 尺寸
        self.encoder_channels = 128     # 列表
        self.encoder_blocks= 3
        self.encoder_pool =  800,
        self.encoder_final_kernel_size =  1
        self.encoder_layers =  10
        self.encoder_func = 'relu' 
        self.blocks= 4
        self.layers = 14  
        self.kernel_size =  2 
        self.skip_channels =  128 
        self.residual_channels =  128  
        self.classes =  256
model_args =args() # 定义结构对象

# %%
import torch.nn as nn

print('Starting')
matplotlib.use('agg')

checkpoints = checkpoint.parent.glob(checkpoint.name + '_*.pth')
checkpoints = [c for c in checkpoints if extract_id(c) in decoders]
assert len(checkpoints) >= 1, "No checkpoints found."

print(checkpoint.parent / 'args.pth')
#model_args = torch.load(checkpoint.parent / 'args.pth')[0]
encoder = wavenet_models.Encoder(model_args)
encoder.load_state_dict(torch.load(checkpoints[0])['encoder_state'])
encoder.eval()
encoder = encoder.cuda()

decoders = []
decoder_ids = []
for checkpoint in checkpoints:
    decoder = WaveNet(model_args)
    #decoder = nn.DataParallel(decoder)
    checkpoint_state = torch.load(checkpoint)['decoder_state']
    #pop_list = ["layers.40.causal.weight", "layers.40.causal.bias", "layers.40.condition.weight", "layers.40.condition.bias", "layers.40.residual.weight", "layers.40.residual.bias", "layers.40.skip.weight", "layers.40.skip.bias", "layers.41.causal.weight", "layers.41.causal.bias", "layers.41.condition.weight", "layers.41.condition.bias", "layers.41.residual.weight", "layers.41.residual.bias", "layers.41.skip.weight", "layers.41.skip.bias", "layers.42.causal.weight", "layers.42.causal.bias", "layers.42.condition.weight", "layers.42.condition.bias", "layers.42.residual.weight", "layers.42.residual.bias", "layers.42.skip.weight", "layers.42.skip.bias", "layers.43.causal.weight", "layers.43.causal.bias", "layers.43.condition.weight", "layers.43.condition.bias", "layers.43.residual.weight", "layers.43.residual.bias", "layers.43.skip.weight", "layers.43.skip.bias", "layers.44.causal.weight", "layers.44.causal.bias", "layers.44.condition.weight", "layers.44.condition.bias", "layers.44.residual.weight", "layers.44.residual.bias", "layers.44.skip.weight", "layers.44.skip.bias", "layers.45.causal.weight", "layers.45.causal.bias", "layers.45.condition.weight", "layers.45.condition.bias", "layers.45.residual.weight", "layers.45.residual.bias", "layers.45.skip.weight", "layers.45.skip.bias", "layers.46.causal.weight", "layers.46.causal.bias", "layers.46.condition.weight", "layers.46.condition.bias", "layers.46.residual.weight", "layers.46.residual.bias", "layers.46.skip.weight", "layers.46.skip.bias", "layers.47.causal.weight", "layers.47.causal.bias", "layers.47.condition.weight", "layers.47.condition.bias", "layers.47.residual.weight", "layers.47.residual.bias", "layers.47.skip.weight", "layers.47.skip.bias", "layers.48.causal.weight", "layers.48.causal.bias", "layers.48.condition.weight", "layers.48.condition.bias", "layers.48.residual.weight", "layers.48.residual.bias", "layers.48.skip.weight", "layers.48.skip.bias", "layers.49.causal.weight", "layers.49.causal.bias", "layers.49.condition.weight", "layers.49.condition.bias", "layers.49.residual.weight", "layers.49.residual.bias", "layers.49.skip.weight", "layers.49.skip.bias", "layers.50.causal.weight", "layers.50.causal.bias", "layers.50.condition.weight", "layers.50.condition.bias", "layers.50.residual.weight", "layers.50.residual.bias", "layers.50.skip.weight", "layers.50.skip.bias", "layers.51.causal.weight", "layers.51.causal.bias", "layers.51.condition.weight", "layers.51.condition.bias", "layers.51.residual.weight", "layers.51.residual.bias", "layers.51.skip.weight", "layers.51.skip.bias", "layers.52.causal.weight", "layers.52.causal.bias", "layers.52.condition.weight", "layers.52.condition.bias", "layers.52.residual.weight", "layers.52.residual.bias", "layers.52.skip.weight", "layers.52.skip.bias", "layers.53.causal.weight", "layers.53.causal.bias", "layers.53.condition.weight", "layers.53.condition.bias", "layers.53.residual.weight", "layers.53.residual.bias", "layers.53.skip.weight", "layers.53.skip.bias", "layers.54.causal.weight", "layers.54.causal.bias", "layers.54.condition.weight", "layers.54.condition.bias", "layers.54.residual.weight", "layers.54.residual.bias", "layers.54.skip.weight", "layers.54.skip.bias", "layers.55.causal.weight", "layers.55.causal.bias", "layers.55.condition.weight", "layers.55.condition.bias", "layers.55.residual.weight", "layers.55.residual.bias", "layers.55.skip.weight", "layers.55.skip.bias"]
    #for items in pop_list:
      #  checkpoint_state.pop(items)
    #checkpoint_state.pop(list(["layers.40.causal.weight", "layers.40.causal.bias", "layers.40.condition.weight", "layers.40.condition.bias", "layers.40.residual.weight", "layers.40.residual.bias", "layers.40.skip.weight", "layers.40.skip.bias", "layers.41.causal.weight", "layers.41.causal.bias", "layers.41.condition.weight", "layers.41.condition.bias", "layers.41.residual.weight", "layers.41.residual.bias", "layers.41.skip.weight", "layers.41.skip.bias", "layers.42.causal.weight", "layers.42.causal.bias", "layers.42.condition.weight", "layers.42.condition.bias", "layers.42.residual.weight", "layers.42.residual.bias", "layers.42.skip.weight", "layers.42.skip.bias", "layers.43.causal.weight", "layers.43.causal.bias", "layers.43.condition.weight", "layers.43.condition.bias", "layers.43.residual.weight", "layers.43.residual.bias", "layers.43.skip.weight", "layers.43.skip.bias", "layers.44.causal.weight", "layers.44.causal.bias", "layers.44.condition.weight", "layers.44.condition.bias", "layers.44.residual.weight", "layers.44.residual.bias", "layers.44.skip.weight", "layers.44.skip.bias", "layers.45.causal.weight", "layers.45.causal.bias", "layers.45.condition.weight", "layers.45.condition.bias", "layers.45.residual.weight", "layers.45.residual.bias", "layers.45.skip.weight", "layers.45.skip.bias", "layers.46.causal.weight", "layers.46.causal.bias", "layers.46.condition.weight", "layers.46.condition.bias", "layers.46.residual.weight", "layers.46.residual.bias", "layers.46.skip.weight", "layers.46.skip.bias", "layers.47.causal.weight", "layers.47.causal.bias", "layers.47.condition.weight", "layers.47.condition.bias", "layers.47.residual.weight", "layers.47.residual.bias", "layers.47.skip.weight", "layers.47.skip.bias", "layers.48.causal.weight", "layers.48.causal.bias", "layers.48.condition.weight", "layers.48.condition.bias", "layers.48.residual.weight", "layers.48.residual.bias", "layers.48.skip.weight", "layers.48.skip.bias", "layers.49.causal.weight", "layers.49.causal.bias", "layers.49.condition.weight", "layers.49.condition.bias", "layers.49.residual.weight", "layers.49.residual.bias", "layers.49.skip.weight", "layers.49.skip.bias", "layers.50.causal.weight", "layers.50.causal.bias", "layers.50.condition.weight", "layers.50.condition.bias", "layers.50.residual.weight", "layers.50.residual.bias", "layers.50.skip.weight", "layers.50.skip.bias", "layers.51.causal.weight", "layers.51.causal.bias", "layers.51.condition.weight", "layers.51.condition.bias", "layers.51.residual.weight", "layers.51.residual.bias", "layers.51.skip.weight", "layers.51.skip.bias", "layers.52.causal.weight", "layers.52.causal.bias", "layers.52.condition.weight", "layers.52.condition.bias", "layers.52.residual.weight", "layers.52.residual.bias", "layers.52.skip.weight", "layers.52.skip.bias", "layers.53.causal.weight", "layers.53.causal.bias", "layers.53.condition.weight", "layers.53.condition.bias", "layers.53.residual.weight", "layers.53.residual.bias", "layers.53.skip.weight", "layers.53.skip.bias", "layers.54.causal.weight", "layers.54.causal.bias", "layers.54.condition.weight", "layers.54.condition.bias", "layers.54.residual.weight", "layers.54.residual.bias", "layers.54.skip.weight", "layers.54.skip.bias", "layers.55.causal.weight", "layers.55.causal.bias", "layers.55.condition.weight", "layers.55.condition.bias", "layers.55.residual.weight", "layers.55.residual.bias", "layers.55.skip.weight", "layers.55.skip.bias"]))
    #decoder.load_state_dict(torch.load(checkpoint)['decoder_state'])
    decoder.load_state_dict(checkpoint_state)
    decoder.eval()
    decoder = decoder.cuda()
    decoder = WavenetGenerator(decoder, 1, wav_freq=16000)

    decoders += [decoder]
    decoder_ids += [extract_id(checkpoint)]
# Out:
# Starting
# ..\checkpoints\pretrained_musicnet\args.pth

# %%
xs = []
file_paths_gen = [Path('test.wav')]
for file_path in file_paths:
    data, rate = librosa.load(file_path, sr=16000)
    assert rate == 16000
    data = utils.mu_law(data)
    xs.append(torch.tensor(data).unsqueeze(0).float().cuda())

xs = torch.stack(xs).contiguous()
print(xs)
print(f'xs size: {xs.size()}')
# Out:
# tensor([[[100., 102., 101.,  ..., 129., 129., 131.]]], device='cuda:0')
# xs size: torch.Size([1, 1, 80000])

# %%
for file_path in file_paths:
    data, rate = librosa.load(file_path, sr=16000)
    assert rate == 16000
    data = utils.mu_law(data)
    xs.append(torch.tensor(data).unsqueeze(0).float().cuda())

xs = torch.stack(xs).contiguous()
print(xs)
print(f'xs size: {xs.size()}')

# %%
yy = {}
with torch.no_grad():
    zz = []
    for xs_batch in torch.split(xs, batch_size):
        zz += [encoder(xs_batch)]
    zz = torch.cat(zz, dim=0)

    with utils.timeit("Generation timer"):
        for i, decoder_id in enumerate(decoder_ids):
            yy[decoder_id] = []
            decoder = decoders[i]
            for zz_batch in torch.split(zz, batch_size):
                print(zz_batch.shape)
                splits = torch.split(zz_batch, split_size, -1)
                audio_data = []
                decoder.reset()
                for cond in tqdm.tqdm_notebook(splits):
                    audio_data += [decoder.generate(cond).cpu()]
                audio_data = torch.cat(audio_data, -1)
                yy[decoder_id] += [audio_data]
            yy[decoder_id] = torch.cat(yy[decoder_id], dim=0)
# Out:
# torch.Size([1, 64, 100])
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [21:23<00:00, 64.18s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [22:23<00:00, 67.17s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [18:23<00:00, 55.15s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [15:45<00:00, 47.26s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [16:18<00:00, 48.93s/it]
# torch.Size([1, 64, 100])
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [15:24<00:00, 46.24s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [15:56<00:00, 47.84s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [17:03<00:00, 51.18s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [11:46<00:00, 35.31s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [07:51<00:00, 23.58s/it]
# torch.Size([1, 64, 100])
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [07:48<00:00, 23.44s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [09:38<00:00, 28.95s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:57<00:00, 20.87s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [08:17<00:00, 24.86s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [10:04<00:00, 30.21s/it]
# torch.Size([1, 64, 100])
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [07:55<00:00, 23.77s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [07:28<00:00, 22.41s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [08:50<00:00, 26.52s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:56<00:00, 20.84s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:55<00:00, 20.79s/it]
# torch.Size([1, 64, 100])
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:46<00:00, 20.31s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:46<00:00, 20.33s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:47<00:00, 20.39s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:47<00:00, 20.39s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:47<00:00, 20.40s/it]
# torch.Size([1, 64, 100])
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:47<00:00, 20.37s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:47<00:00, 20.37s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:48<00:00, 20.43s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:50<00:00, 20.52s/it]
# Generating: 100%|██████████████████████████████████████████████████████████████████████| 20/20 [06:47<00:00, 20.37s/it]
# Generation timer took 18675239.642858505 ms

# %%
for decoder_ix, decoder_result in yy.items():
    for sample_result, filepath in zip(decoder_result, file_paths):
        disp(sample_result, decoder_ix)
# Out:
# Decoder: 0
# X min: 32, max: 223
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Decoder: 1
# X min: 29, max: 225
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Decoder: 2
# X min: 45, max: 214
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Decoder: 3
# X min: 41, max: 210
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Decoder: 4
# X min: 19, max: 236
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Decoder: 5
# X min: 20, max: 235
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
